# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_predict, StratifiedKFold
from scipy.stats import randint,uniform
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay,f1_score
from sklearn.model_selection import RandomizedSearchCV

# %%
df= pd.read_csv('./CSC_classified_final_nway_red.csv')
df
# Out:
#        Unnamed: 0             CSC_CSC_ID  CSC_var_inter_prob_b  \
# 0               0  2CXO J171941.7-355418                   NaN
# 1               1  2CXO J171919.8-355632              0.688725
# 2               2  2CXO J171951.2-355325              0.563362
# 3               3  2CXO J171956.0-355451              0.609957
# 4               4  2CXO J171958.2-355333              0.702705
# ...           ...                    ...                   ...
# 47186       47186  2CXO J174626.1-284311                   NaN
# 47187       47187  2CXO J174549.4-284917                   NaN
# 47188       47188  2CXO J174539.0-290000                   NaN
# 47189       47189  2CXO J174539.5-290059                   NaN
# 47190       47190  2CXO J173617.5-283417              0.970153
#
#        CSC_var_inter_sigma_b  CSC_var_inter_index_b  CSC_ks_intra_prob_b  \
# 0                        NaN                 -32768             0.110753
# 1               2.157409e-07                      5             0.940708
# 2               4.632072e-08                      3             0.374751
# 3               5.897142e-08                      4             0.379334
# 4               1.944157e-07                      5             0.351655
# ...                      ...                    ...                  ...
# 47186                    NaN                 -32768                  NaN
# 47187                    NaN                 -32768                  NaN
# 47188                    NaN                 -32768                  NaN
# 47189                    NaN                 -32768                  NaN
# 47190           5.575158e-06                      6             0.139831
#
#        CSC_kp_intra_prob_b  CSC_var_intra_index_b  CSC_var_intra_prob_b  \
# 0                 0.434036                      0              0.479545
# 1                 0.821869                      2              0.749379
# 2                 0.604095                      0              0.417616
# 3                 0.197464                      0              0.369797
# 4                 0.315327                      0              0.349900
# ...                    ...                    ...                   ...
# 47186                  NaN                 -32768                   NaN
# 47187                  NaN                 -32768                   NaN
# 47188                  NaN                 -32768                   NaN
# 47189                  NaN                      1                   NaN
# 47190             0.101280                      0              0.352004
#
#        CLASS_ID CLASS_Class                            CLASS_Source  \
# 0       6019018         YSO                                  SIMBAD
# 1       6018991         YSO                                  SIMBAD
# 2       6019047         YSO                                  SIMBAD
# 3       6019068         YSO                                  SIMBAD
# 4       6019089         YSO                                  SIMBAD
# ...         ...         ...                                     ...
# 47186   5944010         YSO  Michael A. Kuhn et al 2021 ApJS 254 33
# 47187   5433896        STAR                      (Skiff, 2009-2013)
# 47188   5813290        STAR                                  SIMBAD
# 47189   5813379        STAR                                  SIMBAD
# 47190   5427411        STAR                      (Skiff, 2009-2013)
#
#        dist_bayesfactor     dist_post       p_i  CSC_u/b   CSC_s/b   CSC_m/b  \
# 0             10.624448  9.998668e-01  0.999985      NaN       NaN  0.034251
# 1              9.840393  9.991906e-01  1.000000      0.0  0.000000  0.892446
# 2             11.270465  9.999699e-01  1.000000      NaN  0.223416  0.437766
# 3             11.659839  9.999877e-01  1.000000      NaN  0.094358  0.288578
# 4             11.304786  9.999722e-01  1.000000      NaN  0.051214  0.077666
# ...                 ...           ...       ...      ...       ...       ...
# 47186          9.396320  9.978077e-01  1.000000      NaN       NaN       NaN
# 47187          7.274583  7.747192e-01  1.000000      NaN       NaN       NaN
# 47188        -11.061596  1.585775e-18  1.000000      NaN       NaN       NaN
# 47189       -101.120926  0.000000e+00  1.000000      NaN       NaN       NaN
# 47190         10.123624  9.995885e-01  1.000000      0.0  0.231172  0.084413
#
#         CSC_h/b
# 0      0.993514
# 1      0.000000
# 2      0.373852
# 3      0.693396
# 4      0.827113
# ...         ...
# 47186       NaN
# 47187       NaN
# 47188       NaN
# 47189       NaN
# 47190  0.551943
#
# [47191 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CSC_CSC_ID', 'CSC_var_inter_prob_b',
#        'CSC_var_inter_sigma_b', 'CSC_var_inter_index_b', 'CSC_ks_intra_prob_b',
#        'CSC_kp_intra_prob_b', 'CSC_var_intra_index_b', 'CSC_var_intra_prob_b',
#        'CLASS_ID', 'CLASS_Class', 'CLASS_Source', 'dist_bayesfactor',
#        'dist_post', 'p_i', 'CSC_u/b', 'CSC_s/b', 'CSC_m/b', 'CSC_h/b'],
#       dtype='object')

# %%
ft=df.values[:,[2,3,4,5,6,7,8,15,16,17,18]]
ft
# Out:
# array([[nan, nan, -32768, ..., nan, 0.0342510233907318,
#         0.9935137403120856],
#        [0.68872468581017, 2.1574094492893e-07, 5, ..., 0.0,
#         0.8924463542298487, 0.0],
#        [0.5633617454848601, 4.6320716800618e-08, 3, ...,
#         0.2234159989734346, 0.437766312091542, 0.373851719840085],
#        ...,
#        [nan, nan, -32768, ..., nan, nan, nan],
#        [nan, nan, -32768, ..., nan, nan, nan],
#        [0.970152595457372, 5.5751584932259e-06, 6, ...,
#         0.2311717535287629, 0.0844134603451815, 0.5519425431520539]],
#       dtype=object)

# %%
cl=df.values[:,10]

# %%
def normalise(ft):
    l,b= ft.shape
    for i in range(b):
        ft[:,i]= (ft[:,i]-np.nanmin(ft[:,i]))/(np.nanmax(ft[:,i])-np.nanmin(ft[:,i]))
    return ft

def high_neg_impute(ft):
    l,b= ft.shape
    for i in range(b):
        for j in range(l):
            if np.isnan(ft[j,i]):
                ft[j,i]= -1e+5
    return ft

# %%
ft=normalise(ft)
ft=high_neg_impute(ft)
# Out:
# /tmp/ipykernel_20633/4140430615.py:4: RuntimeWarning: invalid value encountered in divide
#   ft[:,i]= (ft[:,i]-np.nanmin(ft[:,i]))/(np.nanmax(ft[:,i])-np.nanmin(ft[:,i]))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(cl)
y=le.transform(cl)

# %%
rf= RandomForestClassifier()

# %%
smote_pipeline = Pipeline([
    ('smote', SMOTE(sampling_strategy='auto',k_neighbors=4)),
    ('rf', rf)
])

# Use StratifiedKFold for cross-validation
cv = StratifiedKFold(n_splits=20, shuffle=True)

# Train the LightGBM model using cross-validation with SMOTE
y_pred = cross_val_predict(smote_pipeline, ft, y,cv=cv)

# %%
from sklearn.metrics import confusion_matrix
cf_matrix= confusion_matrix(y, y_pred)
cf_matrix= cf_matrix.astype('float64')
l=cf_matrix.shape[0]
for i in range(l):
    cf_matrix[i]=(cf_matrix[i]/np.sum(cf_matrix[i]))*100
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay(confusion_matrix=cf_matrix,
                               display_labels=le.classes_).plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,y_pred,target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          AGN       0.77      0.69      0.73     28869
#           CV       0.00      0.02      0.01       103
#         HMXB       0.05      0.14      0.07       396
#         LMXB       0.05      0.29      0.09       384
#       PULSAR       0.01      0.03      0.02       206
#         STAR       0.24      0.21      0.22      7683
#          ULX       0.02      0.09      0.03        86
#          YSO       0.42      0.43      0.43      9464
#
#     accuracy                           0.55     47191
#    macro avg       0.20      0.24      0.20     47191
# weighted avg       0.60      0.55      0.57     47191

# %%
param_dist = {'rf__n_estimators': randint(10,200),
              'rf__max_depth': randint(6,20),
            'rf__min_samples_leaf': randint(1,60),
             'rf__max_features': uniform(0.1,1.0)}

# Create a random forest classifier
rf = RandomForestClassifier()

#create pipeline
smote_pipeline = Pipeline([
    ('smote', SMOTE(sampling_strategy='auto',k_neighbors=4)),
    ('rf', rf)
])

# Use StratifiedKFold for cross-validation
cv = StratifiedKFold(n_splits=10, shuffle=True)

#create scorer
from sklearn.metrics import make_scorer
scorer = make_scorer(f1_score, average = 'macro')

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(smote_pipeline, 
                                 param_distributions = param_dist, 
                                 n_iter=15, 
                                 cv=cv,scoring=scorer)

# Fit the random search object to the data
rand_search.fit(ft, y)
# Out:
# /home/asm/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/imblearn/pipeline.py", line 333, in fit
#     self._final_estimator.fit(Xt, yt, **last_step_params["fit"])
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/asm/miniconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 1.0510449271484237 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/asm/miniconda3/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /home/asm/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.17692996 0.16305488 0.19415045 0.17712323 0.1944225  0.18299162
#  0.1853982  0.18113016 0.17539037 0.16193259 0.18191032 0.18186165
#  0.18304322        nan 0.17581783]
#   warnings.warn(
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=True),
#                    estimator=Pipeline(steps=[('smote', SMOTE(k_neighbors=4)),
#                                              ('rf', RandomForestClassifier())]),
#                    n_iter=15,
#                    param_distributions={'rf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x732db5670710>,
#                                         'rf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x732db5673440>,
#                                         'rf__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x732db5671fa0>,
#                                         'rf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x732db56703e0>},
#                    scoring=make_scorer(f1_score, response_method='predict', average=macro))

# %%
# Create a variable for the best model
best_rf_smote = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)
# Out:
# Best hyperparameters: {'rf__max_depth': 19, 'rf__max_features': 0.6804567568041654, 'rf__min_samples_leaf': 1, 'rf__n_estimators': 32}

# %%
smote_pipeline_best = Pipeline([
    ('smote', SMOTE(sampling_strategy='auto',k_neighbors=4)),
    ('rf', best_rf_smote)
])

# Use StratifiedKFold for cross-validation
cv = StratifiedKFold(n_splits=20, shuffle=True)

# Train the LightGBM model using cross-validation with SMOTE
y_pred = cross_val_predict(smote_pipeline_best, ft, y,cv=cv)
from sklearn.metrics import confusion_matrix
cf_matrix= confusion_matrix(y, y_pred)
cf_matrix= cf_matrix.astype('float64')
l=cf_matrix.shape[0]
for i in range(l):
    cf_matrix[i]=(cf_matrix[i]/np.sum(cf_matrix[i]))*100
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay(confusion_matrix=cf_matrix,
                               display_labels=le.classes_).plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,y_pred,target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          AGN       0.79      0.65      0.71     28869
#           CV       0.00      0.04      0.01       103
#         HMXB       0.05      0.23      0.08       396
#         LMXB       0.04      0.28      0.08       384
#       PULSAR       0.01      0.05      0.02       206
#         STAR       0.25      0.20      0.22      7683
#          ULX       0.01      0.07      0.01        86
#          YSO       0.41      0.44      0.42      9464
#
#     accuracy                           0.52     47191
#    macro avg       0.20      0.24      0.19     47191
# weighted avg       0.61      0.52      0.56     47191
