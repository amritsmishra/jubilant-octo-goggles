# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_predict, StratifiedKFold
from scipy.stats import randint,uniform
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay,f1_score
from sklearn.model_selection import RandomizedSearchCV
from imblearn import FunctionSampler
from sklearn.utils import resample
from sklearn.ensemble import VotingClassifier
from sklearn.base import clone

# %%
df= pd.read_csv('./CSC_classified_final_nway_red.csv')
df
# Out:
#        Unnamed: 0             CSC_CSC_ID  CSC_var_inter_prob_b  \
# 0               0  2CXO J171941.7-355418                   NaN
# 1               1  2CXO J171919.8-355632              0.688725
# 2               2  2CXO J171951.2-355325              0.563362
# 3               3  2CXO J171956.0-355451              0.609957
# 4               4  2CXO J171958.2-355333              0.702705
# ...           ...                    ...                   ...
# 47186       47186  2CXO J174626.1-284311                   NaN
# 47187       47187  2CXO J174549.4-284917                   NaN
# 47188       47188  2CXO J174539.0-290000                   NaN
# 47189       47189  2CXO J174539.5-290059                   NaN
# 47190       47190  2CXO J173617.5-283417              0.970153
#
#        CSC_var_inter_sigma_b  CSC_var_inter_index_b  CSC_ks_intra_prob_b  \
# 0                        NaN                 -32768             0.110753
# 1               2.157409e-07                      5             0.940708
# 2               4.632072e-08                      3             0.374751
# 3               5.897142e-08                      4             0.379334
# 4               1.944157e-07                      5             0.351655
# ...                      ...                    ...                  ...
# 47186                    NaN                 -32768                  NaN
# 47187                    NaN                 -32768                  NaN
# 47188                    NaN                 -32768                  NaN
# 47189                    NaN                 -32768                  NaN
# 47190           5.575158e-06                      6             0.139831
#
#        CSC_kp_intra_prob_b  CSC_var_intra_index_b  CSC_var_intra_prob_b  \
# 0                 0.434036                      0              0.479545
# 1                 0.821869                      2              0.749379
# 2                 0.604095                      0              0.417616
# 3                 0.197464                      0              0.369797
# 4                 0.315327                      0              0.349900
# ...                    ...                    ...                   ...
# 47186                  NaN                 -32768                   NaN
# 47187                  NaN                 -32768                   NaN
# 47188                  NaN                 -32768                   NaN
# 47189                  NaN                      1                   NaN
# 47190             0.101280                      0              0.352004
#
#        CLASS_ID CLASS_Class                            CLASS_Source  \
# 0       6019018         YSO                                  SIMBAD
# 1       6018991         YSO                                  SIMBAD
# 2       6019047         YSO                                  SIMBAD
# 3       6019068         YSO                                  SIMBAD
# 4       6019089         YSO                                  SIMBAD
# ...         ...         ...                                     ...
# 47186   5944010         YSO  Michael A. Kuhn et al 2021 ApJS 254 33
# 47187   5433896        STAR                      (Skiff, 2009-2013)
# 47188   5813290        STAR                                  SIMBAD
# 47189   5813379        STAR                                  SIMBAD
# 47190   5427411        STAR                      (Skiff, 2009-2013)
#
#        dist_bayesfactor     dist_post       p_i  CSC_u/b   CSC_s/b   CSC_m/b  \
# 0             10.624448  9.998668e-01  0.999985      NaN       NaN  0.034251
# 1              9.840393  9.991906e-01  1.000000      0.0  0.000000  0.892446
# 2             11.270465  9.999699e-01  1.000000      NaN  0.223416  0.437766
# 3             11.659839  9.999877e-01  1.000000      NaN  0.094358  0.288578
# 4             11.304786  9.999722e-01  1.000000      NaN  0.051214  0.077666
# ...                 ...           ...       ...      ...       ...       ...
# 47186          9.396320  9.978077e-01  1.000000      NaN       NaN       NaN
# 47187          7.274583  7.747192e-01  1.000000      NaN       NaN       NaN
# 47188        -11.061596  1.585775e-18  1.000000      NaN       NaN       NaN
# 47189       -101.120926  0.000000e+00  1.000000      NaN       NaN       NaN
# 47190         10.123624  9.995885e-01  1.000000      0.0  0.231172  0.084413
#
#         CSC_h/b
# 0      0.993514
# 1      0.000000
# 2      0.373852
# 3      0.693396
# 4      0.827113
# ...         ...
# 47186       NaN
# 47187       NaN
# 47188       NaN
# 47189       NaN
# 47190  0.551943
#
# [47191 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CSC_CSC_ID', 'CSC_var_inter_prob_b',
#        'CSC_var_inter_sigma_b', 'CSC_var_inter_index_b', 'CSC_ks_intra_prob_b',
#        'CSC_kp_intra_prob_b', 'CSC_var_intra_index_b', 'CSC_var_intra_prob_b',
#        'CLASS_ID', 'CLASS_Class', 'CLASS_Source', 'dist_bayesfactor',
#        'dist_post', 'p_i', 'CSC_u/b', 'CSC_s/b', 'CSC_m/b', 'CSC_h/b'],
#       dtype='object')

# %%
ft=df.values[:,[2,3,4,5,6,7,8,15,16,17,18]]
ft
# Out:
# array([[nan, nan, -32768, ..., nan, 0.0342510233907318,
#         0.9935137403120856],
#        [0.68872468581017, 2.1574094492893e-07, 5, ..., 0.0,
#         0.8924463542298487, 0.0],
#        [0.5633617454848601, 4.6320716800618e-08, 3, ...,
#         0.2234159989734346, 0.437766312091542, 0.373851719840085],
#        ...,
#        [nan, nan, -32768, ..., nan, nan, nan],
#        [nan, nan, -32768, ..., nan, nan, nan],
#        [0.970152595457372, 5.5751584932259e-06, 6, ...,
#         0.2311717535287629, 0.0844134603451815, 0.5519425431520539]],
#       dtype=object)

# %%
cl=df.values[:,10]

# %%
def normalise(ft):
    l,b= ft.shape
    for i in range(b):
        ft[:,i]= (ft[:,i]-np.nanmin(ft[:,i]))/(np.nanmax(ft[:,i])-np.nanmin(ft[:,i]))
    return ft

def high_neg_impute(ft):
    l,b= ft.shape
    for i in range(b):
        for j in range(l):
            if np.isnan(ft[j,i]):
                ft[j,i]= -1e+8
    return ft

# %%
ft=normalise(ft)
ft=high_neg_impute(ft)
# Out:
# /tmp/ipykernel_3996/43106251.py:4: RuntimeWarning: invalid value encountered in divide
#   ft[:,i]= (ft[:,i]-np.nanmin(ft[:,i]))/(np.nanmax(ft[:,i])-np.nanmin(ft[:,i]))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(cl)
y=le.transform(cl)

# %%
ft
# Out:
# array([[-100000000.0, -100000000.0, 0.0, ..., -100000000.0, 0.0, 0.0],
#        [0.68872468581017, 1.1676860376727292e-05, 0.9999084696119112,
#         ..., 0.0, 0.0, 0.0],
#        [0.5633617454848601, 2.507074790530046e-06, 0.9998474493531853,
#         ..., 0.0, 0.0, 0.0],
#        ...,
#        [-100000000.0, -100000000.0, 0.0, ..., -100000000.0, -100000000.0,
#         -100000000.0],
#        [-100000000.0, -100000000.0, 0.0, ..., -100000000.0, -100000000.0,
#         -100000000.0],
#        [0.970152595457372, 0.00030175266966890894, 0.9999389797412741,
#         ..., 0.0, 0.0, 0.0]], dtype=object)

# %%
cl
# Out:
# array(['YSO', 'YSO', 'YSO', ..., 'STAR', 'STAR', 'STAR'], dtype=object)

# %%
def remove_missing_data_effects(X,Y):
    X_neg= X
    X_neg[X_neg<0]= -1e+8
    return X_neg,Y

# %%
y[cl=="AGN"]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
def break_training_data(X,Y):
    r,c=X.shape
    XY= np.empty((r,c+1))
    for i in range(c):
        XY[i,0:-1]=X[i,:]
        XY[i,-1]=Y[i]
    XY_nomaj= XY[Y!=0]
    print(XY_nomaj)
    XY_maj= XY[Y==0]
    print(np.sum(Y==0))
    print(XY_maj)
    n=4
    # print(X.shape,XY.shape)
    XY_maj_chunks= np.array_split(XY_maj,n)
    # print(X)
    # print(Y)    
    # print(XY)
    X_chunks=[]
    Y_chunks=[]
    for i in range(n):
        chunk=XY_maj_chunks[i]
        # print(chunk)
        X_chunks_temp= chunk[:,0:-1]
        # print(X_chunks_temp)
        X_chunks_temp= np.append(X_chunks_temp,XY_nomaj[:,0:-1],axis=0)
        Y_chunks_temp= chunk[:,-1].astype('int')
        Y_chunks_temp= np.append(Y_chunks_temp,XY_nomaj[:,-1].astype('int'),axis=0)
        X_chunks=X_chunks+[X_chunks_temp]
        Y_chunks=Y_chunks+[Y_chunks_temp]
    return X_chunks, Y_chunks

# %%
class CustomEnsemble():
    def __init__(self, base_estimator=RandomForestClassifier(), n_estimators=100, 
		max_depth=None, min_samples_leaf=1,n_classifiers=4):
    
        self._estimator_type = "classifier"
        self.base_estimator = base_estimator
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.min_samples_leaf = min_samples_leaf
        self.n_classifiers = n_classifiers
        self.estimators = self._generate_estimators()

   
    def _generate_estimators(self):
        estimators = []

        for i in range(self.n_classifiers):
            est = clone(self.base_estimator)
    
            est.n_estimators =self.n_estimators
            est.max_depth = self.max_depth
            est.min_samples_leaf = self.min_samples_leaf
            pipe = Pipeline([
                ('smote', SMOTE(sampling_strategy='auto')),
                ('missing_data_effects_remove', FunctionSampler(func=remove_missing_data_effects, validate = False)),
                ('rf', est)
            ])
            estimators.append((f"classifier_{i}", pipe))
        return estimators
    def _divide_n_train(self,X,y):
        X_ch,y_ch= break_training_data(X,y)
        for i in range(self.n_classifiers):
            # print(self.estimators[i][1],X_ch[i],y_ch[i])
            self.estimators[i][1].fit(X_ch[i],y_ch[i])


    
    def fit(self, X, y):
        return self._divide_n_train(X,y)

    def predict(self, X):
        voting_class = VotingClassifier(self.estimators, voting="soft")
        return voting_class.predict(X)

# %%
ens= CustomEnsemble()
ens.fit(ft,y)
# Out:
# [[-1.00000000e+008 -1.00000000e+008  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  7.00000000e+000]
#  [ 6.88724686e-001  1.16768604e-005  9.99908470e-001 ...  0.00000000e+000
#    0.00000000e+000  7.00000000e+000]
#  [ 5.63361745e-001  2.50707479e-006  9.99847449e-001 ...  0.00000000e+000
#    0.00000000e+000  7.00000000e+000]
#  ...
#  [-4.93890407e+061  0.00000000e+000  3.20366943e-043 ...  3.01636114e-004
#    5.80545820e-005  1.69714122e-314]
#  [ 0.00000000e+000 -4.93890407e+061  8.99422045e-006 ...  5.66738549e-007
#   -4.93890407e+061  0.00000000e+000]
#  [ 1.93435508e-043  1.40971428e-006  7.79343487e-003 ...  1.69714122e-314
#    0.00000000e+000  1.79777880e-046]]
# 28869
# [[ 0.00000000e+000  0.00000000e+000  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  ...
#  [ 1.64609431e-004  1.77274720e-004  1.69714122e-314 ... -4.93890211e+061
#    1.69714122e-314  1.48027834e-006]
#  [ 1.92930201e-005 -4.93890407e+061  0.00000000e+000 ...  1.69714122e-314
#    2.03788327e-003  2.96185782e-004]
#  [ 1.69714122e-314  0.00000000e+000  1.24429830e-046 ...  4.03342826e-004
#    1.16078663e-004 -4.93890407e+061]]
# /tmp/ipykernel_3996/3069088925.py:26: RuntimeWarning: invalid value encountered in cast
#   Y_chunks_temp= chunk[:,-1].astype('int')
# /tmp/ipykernel_3996/3069088925.py:27: RuntimeWarning: invalid value encountered in cast
#   Y_chunks_temp= np.append(Y_chunks_temp,XY_nomaj[:,-1].astype('int'),axis=0)

# %%
ens.predict(ft)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 ens.predict(ft)
#
# Cell In[65], line 43, in CustomEnsemble.predict(self, X)
#      41 def predict(self, X):
#      42     voting_class = VotingClassifier(self.estimators, voting="soft")
# ---> 43     return voting_class.predict(X)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/ensemble/_voting.py:438, in VotingClassifier.predict(self, X)
#     425 def predict(self, X):
#     426     """Predict class labels for X.
#     427
#     428     Parameters
#    (...)
#     436         Predicted class labels.
#     437     """
# --> 438     check_is_fitted(self)
#     439     if self.voting == "soft":
#     440         maj = np.argmax(self.predict_proba(X), axis=1)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This VotingClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
