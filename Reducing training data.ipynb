# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('CSC_classified_final_nway_red.csv')
df
# Out:
#                   CSC_CSC_ID  CSC_flux_aper_avg_b  CSC_flux_aper_avg_u  \
# 0      2CXO J171941.7-355418         6.653081e-15                  NaN
# 1      2CXO J171919.8-355632         1.388800e-15                  0.0
# 2      2CXO J171951.2-355325         2.375017e-15                  NaN
# 3      2CXO J171956.0-355451         3.152634e-15                  NaN
# 4      2CXO J171958.2-355333         3.213521e-15                  NaN
# ...                      ...                  ...                  ...
# 47186  2CXO J174626.1-284311                  NaN                  NaN
# 47187  2CXO J174549.4-284917                  NaN                  NaN
# 47188  2CXO J174539.0-290000                  NaN                  NaN
# 47189  2CXO J174539.5-290059                  NaN                  NaN
# 47190  2CXO J173617.5-283417         5.901493e-14                  0.0
#
#        CSC_flux_aper_avg_s  CSC_flux_aper_avg_m  CSC_flux_aper_avg_h  \
# ...

# %%
df['CSC_u/b']=df['CSC_flux_aper_avg_u']/df['CSC_flux_aper_avg_b']
df['CSC_s/b']=df['CSC_flux_aper_avg_s']/df['CSC_flux_aper_avg_b']
df['CSC_m/b']=df['CSC_flux_aper_avg_m']/df['CSC_flux_aper_avg_b']
df['CSC_h/b']=df['CSC_flux_aper_avg_h']/df['CSC_flux_aper_avg_b']

# %%
df
# Out:
#                   CSC_CSC_ID  CSC_flux_aper_avg_b  CSC_flux_aper_avg_u  \
# 0      2CXO J171941.7-355418         6.653081e-15                  NaN
# 1      2CXO J171919.8-355632         1.388800e-15                  0.0
# 2      2CXO J171951.2-355325         2.375017e-15                  NaN
# 3      2CXO J171956.0-355451         3.152634e-15                  NaN
# 4      2CXO J171958.2-355333         3.213521e-15                  NaN
# ...                      ...                  ...                  ...
# 47186  2CXO J174626.1-284311                  NaN                  NaN
# 47187  2CXO J174549.4-284917                  NaN                  NaN
# 47188  2CXO J174539.0-290000                  NaN                  NaN
# 47189  2CXO J174539.5-290059                  NaN                  NaN
# 47190  2CXO J173617.5-283417         5.901493e-14                  0.0
#
#        CSC_flux_aper_avg_s  CSC_flux_aper_avg_m  CSC_flux_aper_avg_h  \
# ...

# %%
df= df.drop(columns=['CSC_flux_aper_avg_b','CSC_flux_aper_avg_u','CSC_flux_aper_avg_s','CSC_flux_aper_avg_m','CSC_flux_aper_avg_h'])
df
# Out:
#                   CSC_CSC_ID  CSC_var_inter_prob_b  CSC_var_inter_sigma_b  \
# 0      2CXO J171941.7-355418                   NaN                    NaN
# 1      2CXO J171919.8-355632              0.688725           2.157409e-07
# 2      2CXO J171951.2-355325              0.563362           4.632072e-08
# 3      2CXO J171956.0-355451              0.609957           5.897142e-08
# 4      2CXO J171958.2-355333              0.702705           1.944157e-07
# ...                      ...                   ...                    ...
# 47186  2CXO J174626.1-284311                   NaN                    NaN
# 47187  2CXO J174549.4-284917                   NaN                    NaN
# 47188  2CXO J174539.0-290000                   NaN                    NaN
# 47189  2CXO J174539.5-290059                   NaN                    NaN
# 47190  2CXO J173617.5-283417              0.970153           5.575158e-06
#
#        CSC_var_inter_index_b  CSC_ks_intra_prob_b  CSC_kp_intra_prob_b  \
# ...

# %%
df.to_csv('CSC_classified_final_nway_red.csv')
